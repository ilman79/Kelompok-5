# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; warnings.simplefilter('ignore')
from datetime import datetime

# %%
jakarta = "C:/Users/User/Downloads/jakarta.csv"
data = (pd.read_csv(jakarta, low_memory = False, encoding = 'utf8'))
data
# Out:
#       created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 0     06-12-2021  202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat
# 1     02-12-2021   30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat
# 2     06-12-2021   19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat
# 3     06-12-2021   33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# 4     06-12-2021   30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# ...          ...    ...    ...  ...  ...     ...      ...            ...
# 1019         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1020         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1021         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1022         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1023         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
#
#      sertifikat  listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18  \
# ...

# %%
data.columns
# Out:
# Index(['created_at', 'LT', 'LB', 'KT', 'KM', 'garasi', 'carport', 'lokasi',
#        'sertifikat', 'listrik', 'hadap', 'harga', 'URL', 'deskripsi',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
B, K = data.shape
print('Baris = ', B, ', Kolom = ', K)
# Out:
# Baris =  1024 , Kolom =  26

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024 entries, 0 to 1023
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   created_at   121 non-null    object
#  1   LT           121 non-null    float64
#  2   LB           121 non-null    float64
#  3   KT           121 non-null    float64
#  4   KM           121 non-null    float64
#  5   garasi       44 non-null     float64
#  6   carport      90 non-null     float64
#  7   lokasi       121 non-null    object
#  8   sertifikat   119 non-null    object
#  9   listrik      120 non-null    float64
#  10  hadap        36 non-null     object
#  11  harga        121 non-null    float64
#  12  URL          121 non-null    object
#  13  deskripsi    112 non-null    object
#  14  Unnamed: 14  0 non-null      float64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
data_baru = data.drop(columns = ['URL','deskripsi','hadap','Unnamed: 14','Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21','Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24','Unnamed: 25'])
data_baru
# Out:
#       created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 0     06-12-2021  202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat
# 1     02-12-2021   30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat
# 2     06-12-2021   19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat
# 3     06-12-2021   33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# 4     06-12-2021   30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# ...          ...    ...    ...  ...  ...     ...      ...            ...
# 1019         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1020         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1021         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1022         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 1023         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
#
#      sertifikat  listrik         harga
# 0           SHM   2200.0  4.500000e+09
# ...

# %%
data_baru.isnull().sum()
# Out:
# created_at    903
# LT            903
# LB            903
# KT            903
# KM            903
# garasi        980
# carport       934
# lokasi        903
# sertifikat    905
# listrik       904
# harga         903
# dtype: int64

# %%
data_baru.head(125)
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 0    06-12-2021  202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat
# 1    02-12-2021   30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat
# 2    06-12-2021   19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat
# 3    06-12-2021   33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# 4    06-12-2021   30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# ..          ...    ...    ...  ...  ...     ...      ...            ...
# 120  06-12-2021  144.0  250.0  5.0  5.0     NaN      2.0  Jakarta Timur
# 121         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 122         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 123         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
# 124         NaN    NaN    NaN  NaN  NaN     NaN      NaN            NaN
#
#     sertifikat  listrik         harga
# 0          SHM   2200.0  4.500000e+09
# ...

# %%
data_baru.drop(data_baru.tail(903).index,inplace=True)
data_baru
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 0    06-12-2021  202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat
# 1    02-12-2021   30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat
# 2    06-12-2021   19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat
# 3    06-12-2021   33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# 4    06-12-2021   30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# ..          ...    ...    ...  ...  ...     ...      ...            ...
# 116  22-11-2021  220.0  239.0  5.0  4.0     1.0      2.0  Jakarta Timur
# 117  06-12-2021   70.0   57.0  3.0  2.0     NaN      2.0  Jakarta Timur
# 118  06-12-2021  315.0  280.0  4.0  3.0     1.0      2.0  Jakarta Timur
# 119  06-12-2021  135.0  190.0  5.0  5.0     NaN      2.0  Jakarta Timur
# 120  06-12-2021  144.0  250.0  5.0  5.0     NaN      2.0  Jakarta Timur
#
#     sertifikat  listrik         harga
# 0          SHM   2200.0  4.500000e+09
# ...

# %%
data_baru['Wilayah'] = 'Jakarta'
data_baru
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 0    06-12-2021  202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat
# 1    02-12-2021   30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat
# 2    06-12-2021   19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat
# 3    06-12-2021   33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# 4    06-12-2021   30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# ..          ...    ...    ...  ...  ...     ...      ...            ...
# 116  22-11-2021  220.0  239.0  5.0  4.0     1.0      2.0  Jakarta Timur
# 117  06-12-2021   70.0   57.0  3.0  2.0     NaN      2.0  Jakarta Timur
# 118  06-12-2021  315.0  280.0  4.0  3.0     1.0      2.0  Jakarta Timur
# 119  06-12-2021  135.0  190.0  5.0  5.0     NaN      2.0  Jakarta Timur
# 120  06-12-2021  144.0  250.0  5.0  5.0     NaN      2.0  Jakarta Timur
#
#     sertifikat  listrik         harga  Wilayah
# 0          SHM   2200.0  4.500000e+09  Jakarta
# ...

# %%
# Mengisi missing value variabel garasi dan carport dengan 0
garasi = data_baru.garasi.fillna('0')
data_baru['garasi'] = data_baru['garasi'].fillna(garasi)
carport = data_baru.carport.fillna('0')
data_baru['carport'] = data_baru['carport'].fillna(carport)
data_baru
# Out:
#      created_at     LT     LB   KT   KM garasi carport         lokasi  \
# 0    06-12-2021  202.0  198.0  8.0  3.0      0       0  Jakarta Pusat
# 1    02-12-2021   30.0   55.0  2.0  1.0      0     1.0  Jakarta Pusat
# 2    06-12-2021   19.0   35.0  2.0  1.0      0       0  Jakarta Pusat
# 3    06-12-2021   33.0   42.0  2.0  2.0      0     1.0  Jakarta Pusat
# 4    06-12-2021   30.0   55.0  2.0  2.0      0     1.0  Jakarta Pusat
# ..          ...    ...    ...  ...  ...    ...     ...            ...
# 116  22-11-2021  220.0  239.0  5.0  4.0    1.0     2.0  Jakarta Timur
# 117  06-12-2021   70.0   57.0  3.0  2.0      0     2.0  Jakarta Timur
# 118  06-12-2021  315.0  280.0  4.0  3.0    1.0     2.0  Jakarta Timur
# 119  06-12-2021  135.0  190.0  5.0  5.0      0     2.0  Jakarta Timur
# 120  06-12-2021  144.0  250.0  5.0  5.0      0     2.0  Jakarta Timur
#
#     sertifikat  listrik         harga  Wilayah
# 0          SHM   2200.0  4.500000e+09  Jakarta
# ...

# %%
#mengecek duplikat data
data_baru.duplicated().sum()
# Out:
# 0

# %%
tangerang = "C:/Users/User/Downloads/tangerang.csv"
data1 = (pd.read_csv(tangerang, low_memory = False, encoding = 'utf8'))
data1
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport  \
# 0    12-06-2021   60.0   50.0  3.0  2.0     NaN      NaN
# 1    12-06-2021   72.0   54.0  2.0  1.0     1.0      1.0
# 2    12-06-2021   60.0   48.0  3.0  2.0     2.0      2.0
# 3    12-06-2021  200.0  225.0  5.0  4.0     NaN      NaN
# 4    12-06-2021   76.0  123.0  3.0  3.0     NaN      2.0
# ..          ...    ...    ...  ...  ...     ...      ...
# 123  12-08-2021   91.0   91.0  3.0  2.0     NaN      NaN
# 124         NaN    NaN    NaN  NaN  NaN     NaN      NaN
# 125         NaN    NaN    NaN  NaN  NaN     NaN      NaN
# 126         NaN    NaN    NaN  NaN  NaN     NaN      NaN
# 127         NaN    NaN    NaN  NaN  NaN     NaN      NaN
#
#                         lokasi sertifikat  listrik  ... Unnamed: 16  \
# 0          BSD CITY, TANGERANG        SHM   1300.0  ...         NaN
# 1            CISAUK, TANGERANG        SHM   1300.0  ...         NaN
# 2           CILEDUG, TANGERANG        SHM   2200.0  ...         NaN
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   created_at   124 non-null    object
#  1   LT           124 non-null    float64
#  2   LB           124 non-null    float64
#  3   KT           124 non-null    float64
#  4   KM           124 non-null    float64
#  5   garasi       38 non-null     float64
#  6   carport      92 non-null     float64
#  7   lokasi       124 non-null    object
#  8   sertifikat   122 non-null    object
#  9   listrik      111 non-null    float64
#  10  hadap        49 non-null     object
#  11  harga        124 non-null    float64
#  12  URL          124 non-null    object
#  13  deskripsi    124 non-null    object
#  14  Unnamed: 14  0 non-null      float64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
data1.columns
# Out:
# Index(['created_at', 'LT', 'LB', 'KT', 'KM', 'garasi', 'carport', 'lokasi',
#        'sertifikat', 'listrik', 'hadap', 'harga', 'URL', 'deskripsi',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
B, K = data1.shape
print('Baris = ', B, ', Kolom = ', K)
# Out:
# Baris =  128 , Kolom =  26

# %%
data1_baru = data1.drop(columns = ['URL','deskripsi','hadap','Unnamed: 14','Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21','Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24','Unnamed: 25'])
data1_baru
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport  \
# 0    12-06-2021   60.0   50.0  3.0  2.0     NaN      NaN
# 1    12-06-2021   72.0   54.0  2.0  1.0     1.0      1.0
# 2    12-06-2021   60.0   48.0  3.0  2.0     2.0      2.0
# 3    12-06-2021  200.0  225.0  5.0  4.0     NaN      NaN
# 4    12-06-2021   76.0  123.0  3.0  3.0     NaN      2.0
# ..          ...    ...    ...  ...  ...     ...      ...
# 123  12-08-2021   91.0   91.0  3.0  2.0     NaN      NaN
# 124         NaN    NaN    NaN  NaN  NaN     NaN      NaN
# 125         NaN    NaN    NaN  NaN  NaN     NaN      NaN
# 126         NaN    NaN    NaN  NaN  NaN     NaN      NaN
# 127         NaN    NaN    NaN  NaN  NaN     NaN      NaN
#
#                         lokasi sertifikat  listrik   harga
# 0          BSD CITY, TANGERANG        SHM   1300.0   500.0
# 1            CISAUK, TANGERANG        SHM   1300.0   480.0
# 2           CILEDUG, TANGERANG        SHM   2200.0   600.0
# ...

# %%
data1_baru.isnull().sum()
# Out:
# created_at     4
# LT             4
# LB             4
# KT             4
# KM             4
# garasi        90
# carport       36
# lokasi         4
# sertifikat     6
# listrik       17
# harga          4
# dtype: int64

# %%
data1_baru.tail(10)
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport  \
# 118  12-08-2021  300.0  148.0  4.0  3.0     2.0      2.0
# 119  12-08-2021   60.0   55.0  2.0  2.0     NaN      1.0
# 120  12-08-2021   66.0   70.0  3.0  2.0     NaN      1.0
# 121  12-08-2021  202.0   85.0  4.0  3.0     1.0      1.0
# 122  12-08-2021  108.0  130.0  3.0  3.0     1.0      1.0
# 123  12-08-2021   91.0   91.0  3.0  2.0     NaN      NaN
# 124         NaN    NaN    NaN  NaN  NaN     NaN      NaN
# 125         NaN    NaN    NaN  NaN  NaN     NaN      NaN
# 126         NaN    NaN    NaN  NaN  NaN     NaN      NaN
# 127         NaN    NaN    NaN  NaN  NaN     NaN      NaN
#
#                         lokasi                       sertifikat  listrik  \
# 118     PONDOK CABE, TANGERANG                              SHM   2200.0
# 119  LIPPO KARAWACI, TANGERANG  lainnya(PPJB, GIRIK, ADAT, dll)   2200.0
# 120          Ciater, Tangerang                              SHM   1300.0
# ...

# %%
data1_baru.drop(data1_baru.tail(4).index,inplace=True)
data1_baru
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport  \
# 0    12-06-2021   60.0   50.0  3.0  2.0     NaN      NaN
# 1    12-06-2021   72.0   54.0  2.0  1.0     1.0      1.0
# 2    12-06-2021   60.0   48.0  3.0  2.0     2.0      2.0
# 3    12-06-2021  200.0  225.0  5.0  4.0     NaN      NaN
# 4    12-06-2021   76.0  123.0  3.0  3.0     NaN      2.0
# ..          ...    ...    ...  ...  ...     ...      ...
# 119  12-08-2021   60.0   55.0  2.0  2.0     NaN      1.0
# 120  12-08-2021   66.0   70.0  3.0  2.0     NaN      1.0
# 121  12-08-2021  202.0   85.0  4.0  3.0     1.0      1.0
# 122  12-08-2021  108.0  130.0  3.0  3.0     1.0      1.0
# 123  12-08-2021   91.0   91.0  3.0  2.0     NaN      NaN
#
#                         lokasi                       sertifikat  listrik  \
# 0          BSD CITY, TANGERANG                              SHM   1300.0
# 1            CISAUK, TANGERANG                              SHM   1300.0
# ...

# %%
data1_baru['Wilayah'] = 'Tangerang'
data1_baru
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport  \
# 0    12-06-2021   60.0   50.0  3.0  2.0     NaN      NaN
# 1    12-06-2021   72.0   54.0  2.0  1.0     1.0      1.0
# 2    12-06-2021   60.0   48.0  3.0  2.0     2.0      2.0
# 3    12-06-2021  200.0  225.0  5.0  4.0     NaN      NaN
# 4    12-06-2021   76.0  123.0  3.0  3.0     NaN      2.0
# ..          ...    ...    ...  ...  ...     ...      ...
# 119  12-08-2021   60.0   55.0  2.0  2.0     NaN      1.0
# 120  12-08-2021   66.0   70.0  3.0  2.0     NaN      1.0
# 121  12-08-2021  202.0   85.0  4.0  3.0     1.0      1.0
# 122  12-08-2021  108.0  130.0  3.0  3.0     1.0      1.0
# 123  12-08-2021   91.0   91.0  3.0  2.0     NaN      NaN
#
#                         lokasi                       sertifikat  listrik  \
# 0          BSD CITY, TANGERANG                              SHM   1300.0
# 1            CISAUK, TANGERANG                              SHM   1300.0
# ...

# %%
# Mengisi missing value variabel garasi dan carport dengan 0
garasi = data1_baru.garasi.fillna('0')
data1_baru['garasi'] = data1_baru['garasi'].fillna(garasi)
carport = data1_baru.carport.fillna('0')
data1_baru['carport'] = data1_baru['carport'].fillna(carport)
data1_baru
# Out:
#      created_at     LT     LB   KT   KM garasi carport  \
# 0    12-06-2021   60.0   50.0  3.0  2.0      0       0
# 1    12-06-2021   72.0   54.0  2.0  1.0    1.0     1.0
# 2    12-06-2021   60.0   48.0  3.0  2.0    2.0     2.0
# 3    12-06-2021  200.0  225.0  5.0  4.0      0       0
# 4    12-06-2021   76.0  123.0  3.0  3.0      0     2.0
# ..          ...    ...    ...  ...  ...    ...     ...
# 119  12-08-2021   60.0   55.0  2.0  2.0      0     1.0
# 120  12-08-2021   66.0   70.0  3.0  2.0      0     1.0
# 121  12-08-2021  202.0   85.0  4.0  3.0    1.0     1.0
# 122  12-08-2021  108.0  130.0  3.0  3.0    1.0     1.0
# 123  12-08-2021   91.0   91.0  3.0  2.0      0       0
#
#                         lokasi                       sertifikat  listrik  \
# 0          BSD CITY, TANGERANG                              SHM   1300.0
# 1            CISAUK, TANGERANG                              SHM   1300.0
# 2           CILEDUG, TANGERANG                              SHM   2200.0
# ...

# %%
#mengecek duplikat data
data1_baru.duplicated().sum()
# Out:
# 0

# %%
depok = "C:/Users/User/Downloads/depok.csv"
data2 = (pd.read_csv(depok, low_memory = False, encoding = 'utf8'))
data2
# Out:
#     created_at   LT     LB   KT   KM  garasi  carport     lokasi sertifikat  \
# 0    6-12-2021  165  200.0  4.0  2.0     NaN      1.0  Sukmajaya        SHM
# 1    6-12-2021   50   45.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 2    6-12-2021   50   36.0  2.0  1.0     NaN      1.0   Sawangan        SHM
# 3    6-12-2021   50   45.0  2.0  1.0     NaN      NaN  Cimanggis        SHM
# 4    6-12-2021   72   45.0  2.0  1.0     NaN      1.0   Sawangan        SHM
# ..         ...  ...    ...  ...  ...     ...      ...        ...        ...
# 993        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 994        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 995        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 996        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 997        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
#
# ...

# %%
data2.columns
# Out:
# Index(['created_at', 'LT', 'LB', 'KT', 'KM', 'garasi', 'carport', 'lokasi',
#        'sertifikat', 'listrik', 'hadap', 'harga', 'URL', 'deskripsi',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
B, K = data2.shape
print('Baris = ', B, ', Kolom = ', K)
# Out:
# Baris =  998 , Kolom =  26

# %%
data2_baru = data2.drop(columns = ['URL','deskripsi','hadap','Unnamed: 14','Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21','Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24','Unnamed: 25'])
data2_baru
# Out:
#     created_at   LT     LB   KT   KM  garasi  carport     lokasi sertifikat  \
# 0    6-12-2021  165  200.0  4.0  2.0     NaN      1.0  Sukmajaya        SHM
# 1    6-12-2021   50   45.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 2    6-12-2021   50   36.0  2.0  1.0     NaN      1.0   Sawangan        SHM
# 3    6-12-2021   50   45.0  2.0  1.0     NaN      NaN  Cimanggis        SHM
# 4    6-12-2021   72   45.0  2.0  1.0     NaN      1.0   Sawangan        SHM
# ..         ...  ...    ...  ...  ...     ...      ...        ...        ...
# 993        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 994        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 995        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 996        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 997        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
#
#      listrik   harga
# 0     2200.0  2100.0
# ...

# %%
data2_baru.isnull().sum()
# Out:
# created_at    879
# LT            878
# LB            880
# KT            880
# KM            880
# garasi        973
# carport       904
# lokasi        880
# sertifikat    880
# listrik       895
# harga         880
# dtype: int64

# %%
data2_baru.head(120)
# Out:
#     created_at   LT     LB   KT   KM  garasi  carport     lokasi sertifikat  \
# 0    6-12-2021  165  200.0  4.0  2.0     NaN      1.0  Sukmajaya        SHM
# 1    6-12-2021   50   45.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 2    6-12-2021   50   36.0  2.0  1.0     NaN      1.0   Sawangan        SHM
# 3    6-12-2021   50   45.0  2.0  1.0     NaN      NaN  Cimanggis        SHM
# 4    6-12-2021   72   45.0  2.0  1.0     NaN      1.0   Sawangan        SHM
# ..         ...  ...    ...  ...  ...     ...      ...        ...        ...
# 115  4-12-2021   40   40.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 116  4-12-2021   50   50.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 117  4-12-2021  100   15.0  3.0  3.0     1.0      1.0     Cinere        SHM
# 118        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
# 119        NaN  NaN    NaN  NaN  NaN     NaN      NaN        NaN        NaN
#
#      listrik   harga
# 0     2200.0  2100.0
# ...

# %%
data2_baru.drop(data2_baru.tail(880).index,inplace=True)
data2_baru
# Out:
#     created_at   LT     LB   KT   KM  garasi  carport     lokasi sertifikat  \
# 0    6-12-2021  165  200.0  4.0  2.0     NaN      1.0  Sukmajaya        SHM
# 1    6-12-2021   50   45.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 2    6-12-2021   50   36.0  2.0  1.0     NaN      1.0   Sawangan        SHM
# 3    6-12-2021   50   45.0  2.0  1.0     NaN      NaN  Cimanggis        SHM
# 4    6-12-2021   72   45.0  2.0  1.0     NaN      1.0   Sawangan        SHM
# ..         ...  ...    ...  ...  ...     ...      ...        ...        ...
# 113  4-12-2021   79  115.0  2.0  1.0     1.0      1.0  Sukmajaya        SHM
# 114  4-12-2021   72   45.0  2.0  1.0     NaN      1.0  Cimanggis        SHM
# 115  4-12-2021   40   40.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 116  4-12-2021   50   50.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 117  4-12-2021  100   15.0  3.0  3.0     1.0      1.0     Cinere        SHM
#
#      listrik   harga
# 0     2200.0  2100.0
# ...

# %%
data2_baru['Wilayah'] = 'Depok'
data2_baru
# Out:
#     created_at   LT     LB   KT   KM  garasi  carport     lokasi sertifikat  \
# 0    6-12-2021  165  200.0  4.0  2.0     NaN      1.0  Sukmajaya        SHM
# 1    6-12-2021   50   45.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 2    6-12-2021   50   36.0  2.0  1.0     NaN      1.0   Sawangan        SHM
# 3    6-12-2021   50   45.0  2.0  1.0     NaN      NaN  Cimanggis        SHM
# 4    6-12-2021   72   45.0  2.0  1.0     NaN      1.0   Sawangan        SHM
# ..         ...  ...    ...  ...  ...     ...      ...        ...        ...
# 113  4-12-2021   79  115.0  2.0  1.0     1.0      1.0  Sukmajaya        SHM
# 114  4-12-2021   72   45.0  2.0  1.0     NaN      1.0  Cimanggis        SHM
# 115  4-12-2021   40   40.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 116  4-12-2021   50   50.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 117  4-12-2021  100   15.0  3.0  3.0     1.0      1.0     Cinere        SHM
#
#      listrik   harga Wilayah
# ...

# %%
# Mengisi missing value variabel garasi dan carport dengan 0
garasi = data2_baru.garasi.fillna('0')
data2_baru['garasi'] = data2_baru['garasi'].fillna(garasi)
carport = data2_baru.carport.fillna('0')
data2_baru['carport'] = data2_baru['carport'].fillna(carport)
data2_baru
# Out:
#     created_at   LT     LB   KT   KM garasi carport     lokasi sertifikat  \
# 0    6-12-2021  165  200.0  4.0  2.0      0     1.0  Sukmajaya        SHM
# 1    6-12-2021   50   45.0  2.0  1.0      0       0   Cipayung        SHM
# 2    6-12-2021   50   36.0  2.0  1.0      0     1.0   Sawangan        SHM
# 3    6-12-2021   50   45.0  2.0  1.0      0       0  Cimanggis        SHM
# 4    6-12-2021   72   45.0  2.0  1.0      0     1.0   Sawangan        SHM
# ..         ...  ...    ...  ...  ...    ...     ...        ...        ...
# 113  4-12-2021   79  115.0  2.0  1.0    1.0     1.0  Sukmajaya        SHM
# 114  4-12-2021   72   45.0  2.0  1.0      0     1.0  Cimanggis        SHM
# 115  4-12-2021   40   40.0  2.0  1.0      0       0   Cipayung        SHM
# 116  4-12-2021   50   50.0  2.0  1.0      0       0   Cipayung        SHM
# 117  4-12-2021  100   15.0  3.0  3.0    1.0     1.0     Cinere        SHM
#
#      listrik   harga Wilayah
# 0     2200.0  2100.0   Depok
# ...

# %%
#mengecek duplikat data
data2_baru.duplicated().sum()
# Out:
# 8

# %%
data2_baru.drop_duplicates(inplace=True)
print(data2_baru.duplicated().sum())
# Out:
# 0

# %%
join = pd.concat([data_baru, data1_baru, data2_baru], axis = 0)
join
# Out:
#      created_at     LT     LB   KT   KM garasi carport         lokasi  \
# 0    06-12-2021  202.0  198.0  8.0  3.0      0       0  Jakarta Pusat
# 1    02-12-2021   30.0   55.0  2.0  1.0      0     1.0  Jakarta Pusat
# 2    06-12-2021   19.0   35.0  2.0  1.0      0       0  Jakarta Pusat
# 3    06-12-2021   33.0   42.0  2.0  2.0      0     1.0  Jakarta Pusat
# 4    06-12-2021   30.0   55.0  2.0  2.0      0     1.0  Jakarta Pusat
# ..          ...    ...    ...  ...  ...    ...     ...            ...
# 113   4-12-2021     79  115.0  2.0  1.0    1.0     1.0      Sukmajaya
# 114   4-12-2021     72   45.0  2.0  1.0      0     1.0      Cimanggis
# 115   4-12-2021     40   40.0  2.0  1.0      0       0       Cipayung
# 116   4-12-2021     50   50.0  2.0  1.0      0       0       Cipayung
# 117   4-12-2021    100   15.0  3.0  3.0    1.0     1.0         Cinere
#
#     sertifikat  listrik         harga  Wilayah
# 0          SHM   2200.0  4.500000e+09  Jakarta
# ...
